# %% [markdown]
# W tym miejscu można znaleźć kod źródłowy i instrukcje dotyczące trenowania rekurencyjnej sieci neuronowej typu LSTM do generowania utworów muzycznych. Samo generowanie utworów zawiera skrypt `generuj.py`.
#
# Przed rozpoczęciem pracy należy pamiętać o wyborze TPU jako urządzenia przyśpieszającego uczenie sieci: `Edit → Notebook settings → Hardware accelerator → TPU`.

# %%
import glob
import pickle
import numpy as np
from music21 import converter, instrument, note, chord
from keras.utils import np_utils

import os
import tensorflow as tf
# użyjemy trochę Kerasa (żeby było nieco czytelniej niż w czystym TF), ale nie używamy go w "podstawowej" wersji, tylko w wersji z tf.keras - dlaczego, o tym w dalszych komentarzach
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Przed rozpoczęciem pracy należy pamiętać o ustawieniu odpowiednich ścieżek do plików wejściowych i wyjściowych:
# *   `ścieżka_do_zbioru_uczącego` – pełna ścieżka do katalogu z plikami MIDI, na podstawie których będziemy uczyć naszą sieć, wraz ze wzorcem nazwy otwieranych plików (w tym wypadku – rozszerzenie `.mid`),
# *   `plik_z_nutami` – plik, w którym zostanie zapisany zbiór dopuszczalnych nut i akordów (na podstawie zbioru uczącego),
# *   `ścieżka_do_modelu` – plik, w którym zapiszemy wytrenowany model.
#
# Korzystam tutaj z Dysku Google, a więc należy pamiętać przede wszystkim o załadowaniu plików na własny Dysk Google, jak również o tym, że należy używać ścieżek bezwzględnych, a więc z prefiksem `/content/gdrive/My Drive/`.

# %%
ścieżka_do_zbioru_uczącego = "/content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/*.mid"
plik_z_nutami = "/content/gdrive/My Drive/Colab Notebooks/OMatKo 2019/nuty_chopin"
ścieżka_do_modelu = "/content/gdrive/My Drive/Colab Notebooks/OMatKo 2019/model_chopin.h5"

# %% [markdown]
# Ustawiamy też kilka parametrów, któr możemy zechcieć zmienić w ramach eksperymentów. Oczywiście można je ustawiać bezpośrednio w miejsach, w których będziemy z nich korzystać, ale jeśli są na górze, łatwiej je znaleźć.
#
#
# *   `learning_rate` – współczynnik dotyczący pracy optymalizatora sieci neuronowej; zbyt mały spowoduje zbyt wolne uczenie sieci, zbyt duży – niestabilność uczenia, tzn. sieć może zbyt gwałtownie zmieniać wagi w końcowych iteracjach, kiedy dążymy już do pewnej stabilizacji na najlepszym możliwym poziomie;
# *   `liczba_epok` – inaczej mówiąc liczba iteracji uczenia sieci,
# *  `długość_sekwencji` – liczba nut i akordów, które będziemy rozpatrywać jako sekwencję dźwięków (każdy utwór podzielimy na kilka takich sekwencji).

# %%
learning_rate = 0.002
liczba_epok = 150
długość_sekwencji = 100

# %% [markdown]
# Poniższa komórka pobiera adres jednostki TPU. Używamy TPU z tego względu, iż uczenie sieci rekurencyjnych (różnego typu) trwa bardzo długo, a TPU pozwala to przyśpieszyć do akceptowalnego czasu.
#
# Przykładowo, dla zbioru 100 plików MIDI i takiegj struktury sieci, jaką mamy w tym pliku, jedna epoka na CPU zajmuje ok. 80 minut, na GPU – 6-7 minut, na TPU natomiast 15-20 sekund. Jako że potrzebujemy około 150-180 epok, przyśpieszenie to jest naprawdę istotne.

# %%
try:
  nazwa_urządzenia = os.environ['COLAB_TPU_ADDR']
  ADRES_TPU = 'grpc://' + nazwa_urządzenia
  print('Znaleziono TPU pod adresem: {}'.format(ADRES_TPU))

except KeyError:
  print('Nie znaleziono TPU!')
# Out:
# Znaleziono TPU pod adresem: grpc://10.108.50.66:8470

# %% [markdown]
# Przed użyciem plików z Dysku Google, musimy zamontować nasz dysk. Po uruchomieniu tej komórki pojawi się link autoryzacyjny, gdyż trzeba będzie nadać Colabowi prawa do odczytu i zapisu plików na naszym dysku. Po nadaniu uprawnień uzyksamy kod autoryzacyjny, który trzeba wkleić w polu, które również pojawi się w tym miejscu, po czym należy kliknąć przycisk „Enter” na klawiaturze.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
nuty = []

for plik in glob.glob(ścieżka_do_zbioru_uczącego): # otwieramy każdy plik ze zbioru uczącego
    midi = converter.parse(plik) # konwersja pliku MIDI na nuty i akordy, które możemy odczytać

    print('Przetwarzanie:', plik)

    nuty_do_przetworzenia = None

    # jeśli plik zawiera ścieżki dla kilku instrumentów
    try:
        partytura = instrument.partitionByInstrument(midi)
        nuty_do_przetworzenia = partytura.parts[0].recurse() 
    except:
        nuty_do_przetworzenia = midi.flat.notes

    for dźwięk in nuty_do_przetworzenia:
        if isinstance(dźwięk, note.Note): # jeśli to pojedyncza nuta - zapisz nazwę dźwięku
            nuty.append(str(dźwięk.pitch))
        elif isinstance(dźwięk, chord.Chord): # jeśli to akord - zapisz dźwięki rozdzielone kropkami (jako liczby, tu odsyłam do dokumentacji biblioteki music21)
            nuty.append('.'.join(str(n) for n in dźwięk.normalOrder))

# Utwory prztworzone na nuty zapisujemy do pliku - będzie to nam jeszcze potrzebne przy generowaniu utworów jako baza dla pierwszych dźwięków generowanych przez sieć
with open(plik_z_nutami, 'wb') as ścieżka:
    pickle.dump(nuty, ścieżka)
# Out:
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op35_4.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op23.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op7_1.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p3.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op25_e11.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op35_1.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p5.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op66.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chp_op31.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p17.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op10_e05.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op27_1.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p23.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p11.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op53.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p24.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p15.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p4.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op33_2.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op25_e3.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p7.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op35_3.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p16.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p8.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p9.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p19.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p20.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op25_e2.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op25_e1.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p22.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op25_e12.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p12.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op27_2.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p6.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chp_op18.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p1.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op7_2.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p13.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p21.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op10_e01.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p14.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op33_4.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p2.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p18.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op35_2.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op25_e4.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn-p10.mid
# Przetwarzanie: /content/gdrive/My Drive/Zbiory dla Colaba/Utwory_MIDI/Klasyczna/Chopin/chpn_op10_e12.mid

# %%
długość_sekwencji = 100

# wszystkie nazwy dźwięków - potrzebujemy tylko listy "dopuszczalnych" wartości
nazwy_dźwięków = sorted(set(nuty))

liczba_dźwięków = len(nazwy_dźwięków) # liczba "dopuszczalnych" dźwięków i akordów w naszym "słowniku"

# mapowanie nazw dźwięków na liczby
nuty_int = dict((n, i) for i, n in enumerate(nazwy_dźwięków))

wejście_sieci = []
wyjście_sieci = []

for i in range(0, len(nuty) - długość_sekwencji):
    sekwencja_wejściowa = nuty[i:i + długość_sekwencji] # bierzemy kolejne x dźwięków z naszego zbioru (gdzie x jest ustaloną długością sekwencji)
    sekwencja_wyjściowa = nuty[i + długość_sekwencji] # i dźwięk, który po owej sekwencji nastąpi
    wejście_sieci.append([nuty_int[n] for n in sekwencja_wejściowa]) # do wejścia dodajemy liczbową reprezentację całej sekwencji (tu uwaga - dodajemy ją jako cały "rekord", więc kolejna sekwencja będzie już zupełnie oddzielona)
    wyjście_sieci.append(nuty_int[sekwencja_wyjściowa]) # do wyjścia dodajemy liczbową reprezentację wyjściowego dźwięku

liczba_wzorców = len(wejście_sieci) # ile "rekordów" mamy w naszej bazie - każdy rekord to sekwencja dźwięków + jeden dźwięk po niej rzeczywiście występujący

# trochę magii potrzebnej modelowi do poprawnego czytania danych
wejście_sieci = np.reshape(wejście_sieci, (liczba_wzorców, długość_sekwencji, 1))
# normalizacja
wejście_sieci = wejście_sieci / float(liczba_dźwięków)

# też trochę kerasowo-tensorflowowej magii potrzebnej ze względów formalno-technicznych, tylko tym razem do danych wyjściowych (tzn. oczekiwanych danych wyjściowych, prawidłowych klas - jak kto woli)
# dane wyjściowe muszą być podane w postaci wektora z tzw. kodowaniem gorącojedynkowym, tzn. takiego, gdzie mamy same zera oprócz pola odpowiadającego wartości przez ów wektor reprezentowanej - tam będzie stać jedynka
# (i to automatycznie zrobi funkcja to_categorical)
wyjście_sieci = np_utils.to_categorical(wyjście_sieci)

# %% [markdown]
# Powyżej można zauważyć pewną nieścisłość, wręcz małe „oszustwo” – które jednak nie tyle oszukuje nas, co raczej może wprowadzać w błąd sieć. Otóż zauważmy, co zrobiliśmy z naszymi utworami – połączyliśmy je w jedną wielką partyturę. A teraz – nie rozróżniając już tych utworów, dzielimy tę „superpartyturę” na sekwencje i czasami będziemy próbowali zmusić naszą sieć, żeby na podstawie ostatnich dźwięków poprzeniego utworu przewidziała pierwszy dźwięk kolejnego utworu. Czy to dobrze? Tak średnio, jest to dość sprzeczne z intuicją, choć może też pozwalać na ciekawe „zwroty akcji” w później generowanych partyturach. Niemniej – bezapelacyjnie lepiej byłoby te sekwencje podzielić tak, by sytuacje takie, jak wyżej wymieniona, się nie pojawiały. Jako że nie jest to trudne – pozostawiam to szanownemu Czytelnikowi jako proste ćwiczenie do sprawdzenia, czy poprawi to jakkolwiek wyniki. ;-)
#
# (Należy jednak uważać na bardzo krótkie utwory, tzn. takie, dla których ustalona przez nas długość sekwencji będzie zawierała więcej nut niż ma sam utwór.)

# %%
# tworzony jest obiekt optymalizatora - można użyć też optymalizatora z tf.keras.optimiziers, ale ten jest nieco szybszy
opt = tf.train.RMSPropOptimizer(learning_rate)

# definicja modelu z użyciem Keras Functional API (przy Keras Sequential model nie moglibyśmy użyć TPU);
# poza tym należy poamiętać, że musimy używać warstw z tf.keras.layers, a nie z samego Kerasa (jak wyżej - inaczej nie zadziała)
warstwa_wejściowa=tf.keras.layers.Input(shape=(wejście_sieci.shape[1], wejście_sieci.shape[2]))
x=tf.keras.layers.LSTM(512, return_sequences=True)(warstwa_wejściowa)
x=tf.keras.layers.Dropout(0.3)(x)
x=tf.keras.layers.LSTM(512, return_sequences=True)(x) # każda warstwa LSTM prócz ostatniej musi mieć ustawiony parametr return_sequences=True
x=tf.keras.layers.Dropout(0.3)(x)
x=tf.keras.layers.LSTM(512)(x)
x=tf.keras.layers.Dense(256)(x)
x=tf.keras.layers.Dropout(0.3)(x)

# warstwa wyjściowa - potrzebujemy tylu neuronów, ile dźwięków jest dopuszczalnych w naszym modelu - 
# model będzie wybierać kolejne dźwięki na podstawie tego, z jakim dźwiękiem powiązany jest neuron zwracający największą wartość
warstwa_wyjściowa = tf.keras.layers.Dense(liczba_dźwięków, activation='softmax')(x)
model_f=tf.keras.models.Model(inputs=warstwa_wejściowa, outputs=warstwa_wyjściowa)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_f.compile(loss='categorical_crossentropy', optimizer=opt) # kompilacja modelu


# konwersja modelu biblioteki Keras na model TensorFlow przystosowany do pracy z TPU
tpu_model = tf.contrib.tpu.keras_to_tpu_model(model_f, strategy=tf.contrib.tpu.TPUDistributionStrategy(tf.contrib.cluster_resolver.TPUClusterResolver(ADRES_TPU)))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.108.50.66:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 10172020150407497454)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 4465260527371010534)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 11900663193035206448)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 4173649788514342940)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 7651634523586240104)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 15721787226003534949)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 4441487246651273919)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 7872240343836477768)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 8155394389228668194)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 5724207507412728678)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 11495472916322819978)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.

# %%
# Tworzymy callback do checkpointingu - za każdym razem, kiedy powstanie model o mniejszej wartości funkcji straty - a więc lepiej przystosowany - będzie on zapisywany
# daje nam to też możliwość zakończenia procesu uczenia przed upływem wszystkich iteracji, jeśli zauważymy, że model już nie ma zbyt dużych perspektyw na faktyczną poprawę jakości
callback_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    ścieżka_do_modelu,
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min'
)

# %%
# trenowanie sieci
tpu_model.fit(wejście_sieci, wyjście_sieci, epochs=liczba_epok, batch_size=1024, callbacks=[callback_checkpoint])
# Out:
# Epoch 1/150
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(128, 100, 1), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(128, 317), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 9.49458932876587 secs
# INFO:tensorflow:Setting weights on TPU model.
# 61440/63329 [============================>.] - ETA: 0s - loss: 5.7510INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(108,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(108, 100, 1), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(108, 317), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 12.272863626480103 secs
# 62464/63329 [============================>.] - ETA: 0s - loss: 5.7506INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 64s 1ms/sample - loss: 5.7503
# Epoch 2/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 5.2429INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 15s 234us/sample - loss: 5.2383
# Epoch 3/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.7917INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 15s 235us/sample - loss: 4.7909
# Epoch 4/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 4.8254
# Epoch 5/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.5798INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 15s 244us/sample - loss: 4.5789
# Epoch 6/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.5440INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 15s 244us/sample - loss: 4.5429
# Epoch 7/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.5285INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 16s 252us/sample - loss: 4.5281
# Epoch 8/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.5064INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 16s 256us/sample - loss: 4.5068
# Epoch 9/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.5029INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 17s 268us/sample - loss: 4.5034
# Epoch 10/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.4523INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 18s 277us/sample - loss: 4.4526
# Epoch 11/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.4319INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 17s 276us/sample - loss: 4.4311
# Epoch 12/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.4023INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 23s 361us/sample - loss: 4.4016
# Epoch 13/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.3626INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 18s 287us/sample - loss: 4.3631
# Epoch 14/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.3040INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 19s 300us/sample - loss: 4.3041
# Epoch 15/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.2199INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 19s 296us/sample - loss: 4.2195
# Epoch 16/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 4.0938INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 19s 307us/sample - loss: 4.0936
# Epoch 17/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 3.9447INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 20s 316us/sample - loss: 3.9459
# Epoch 18/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 3.7795INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 20s 323us/sample - loss: 3.7783
# Epoch 19/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 3.5832INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 20s 322us/sample - loss: 3.5825
# Epoch 20/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 3.3947INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 21s 332us/sample - loss: 3.3940
# Epoch 21/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 3.2186INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 21s 335us/sample - loss: 3.2181
# Epoch 22/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 3.0377INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 22s 353us/sample - loss: 3.0374
# Epoch 23/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 2.8429INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 22s 349us/sample - loss: 2.8422
# Epoch 24/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 2.6800INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 22s 354us/sample - loss: 2.6800
# Epoch 25/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 2.5091INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 23s 360us/sample - loss: 2.5093
# Epoch 26/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 2.3508INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 23s 368us/sample - loss: 2.3505
# Epoch 27/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 2.1978INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 24s 384us/sample - loss: 2.1975
# Epoch 28/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 2.0491INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 24s 374us/sample - loss: 2.0473
# Epoch 29/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.9012INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 25s 393us/sample - loss: 1.9001
# Epoch 30/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.7514INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 25s 395us/sample - loss: 1.7545
# Epoch 31/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.6341INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 25s 390us/sample - loss: 1.6329
# Epoch 32/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.5116INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 26s 416us/sample - loss: 1.5125
# Epoch 33/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.3887INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 26s 409us/sample - loss: 1.3907
# Epoch 34/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.2796INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 26s 417us/sample - loss: 1.2800
# Epoch 35/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.1909INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 27s 425us/sample - loss: 1.1903
# Epoch 36/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 1.0869INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 27s 429us/sample - loss: 1.0849
# Epoch 37/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.9980INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 28s 435us/sample - loss: 0.9991
# Epoch 38/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.9219INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 28s 438us/sample - loss: 0.9220
# Epoch 39/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.8603INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 29s 464us/sample - loss: 0.8610
# Epoch 40/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.7862INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 29s 454us/sample - loss: 0.7865
# Epoch 41/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.7188INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 30s 466us/sample - loss: 0.7197
# Epoch 42/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.6726INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 29s 457us/sample - loss: 0.6723
# Epoch 43/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.6269INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 30s 474us/sample - loss: 0.6271
# Epoch 44/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.5708INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 30s 474us/sample - loss: 0.5720
# Epoch 45/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.5454INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 31s 488us/sample - loss: 0.5452
# Epoch 46/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.5113INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 31s 493us/sample - loss: 0.5134
# Epoch 47/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.4648INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 31s 493us/sample - loss: 0.4653
# Epoch 48/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.4361INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 31s 491us/sample - loss: 0.4364
# Epoch 49/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.4245INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 33s 521us/sample - loss: 0.4255
# Epoch 50/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.3739INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 32s 504us/sample - loss: 0.3750
# Epoch 51/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.3556INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 34s 533us/sample - loss: 0.3558
# Epoch 52/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.3435INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 33s 518us/sample - loss: 0.3439
# Epoch 53/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.3264INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 34s 539us/sample - loss: 0.3276
# Epoch 54/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.3168INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 34s 543us/sample - loss: 0.3179
# Epoch 55/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2945INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 34s 538us/sample - loss: 0.2956
# Epoch 56/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2857INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 35s 560us/sample - loss: 0.2869
# Epoch 57/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2779INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 36s 561us/sample - loss: 0.2788
# Epoch 58/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2701INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 36s 569us/sample - loss: 0.2710
# Epoch 59/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2527INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 36s 565us/sample - loss: 0.2540
# Epoch 60/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2460INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 36s 568us/sample - loss: 0.2464
# Epoch 61/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2335INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 36s 568us/sample - loss: 0.2341
# Epoch 62/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2311INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 37s 580us/sample - loss: 0.2317
# Epoch 63/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.2335
# Epoch 64/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.2323
# Epoch 65/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2108INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 38s 603us/sample - loss: 0.2110
# Epoch 66/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2103INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 39s 612us/sample - loss: 0.2108
# Epoch 67/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.2055INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 38s 606us/sample - loss: 0.2050
# Epoch 68/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1982INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 39s 620us/sample - loss: 0.1985
# Epoch 69/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.2094
# Epoch 70/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1954INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 40s 628us/sample - loss: 0.1953
# Epoch 71/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1885INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 40s 635us/sample - loss: 0.1884
# Epoch 72/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1906
# Epoch 73/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1827INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 40s 633us/sample - loss: 0.1830
# Epoch 74/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1838
# Epoch 75/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1873
# Epoch 76/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1804INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 41s 642us/sample - loss: 0.1804
# Epoch 77/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1745INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 40s 638us/sample - loss: 0.1750
# Epoch 78/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1794
# Epoch 79/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1700INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 41s 646us/sample - loss: 0.1700
# Epoch 80/150
# 63329/63329 [==============================] - 10s 155us/sample - loss: 0.1936
# Epoch 81/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1490INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 43s 680us/sample - loss: 0.1491
# Epoch 82/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1584
# Epoch 83/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1624
# Epoch 84/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1626
# Epoch 85/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1507
# Epoch 86/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1492
# Epoch 87/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1517
# Epoch 88/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1553
# Epoch 89/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1446INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 42s 667us/sample - loss: 0.1448
# Epoch 90/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1500
# Epoch 91/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1423INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 43s 675us/sample - loss: 0.1426
# Epoch 92/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1444
# Epoch 93/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1411INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 43s 674us/sample - loss: 0.1408
# Epoch 94/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1419
# Epoch 95/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1415
# Epoch 96/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1313INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 45s 715us/sample - loss: 0.1316
# Epoch 97/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1394
# Epoch 98/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1394
# Epoch 99/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1389
# Epoch 100/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1273INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 43s 685us/sample - loss: 0.1277
# Epoch 101/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1318
# Epoch 102/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1313
# Epoch 103/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1314
# Epoch 104/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1311
# Epoch 105/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1298
# Epoch 106/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1235INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 44s 692us/sample - loss: 0.1237
# Epoch 107/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1240
# Epoch 108/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1252
# Epoch 109/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1284
# Epoch 110/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1181INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 44s 699us/sample - loss: 0.1185
# Epoch 111/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1174INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 46s 729us/sample - loss: 0.1172
# Epoch 112/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1218
# Epoch 113/150
# 63329/63329 [==============================] - 10s 155us/sample - loss: 0.1220
# Epoch 114/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1176
# Epoch 115/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1193
# Epoch 116/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1186
# Epoch 117/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1135INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 46s 726us/sample - loss: 0.1139
# Epoch 118/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1157
# Epoch 119/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1247
# Epoch 120/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1220
# Epoch 121/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1131INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 46s 721us/sample - loss: 0.1130
# Epoch 122/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1201
# Epoch 123/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1188
# Epoch 124/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1089INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 47s 738us/sample - loss: 0.1087
# Epoch 125/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1114
# Epoch 126/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1303
# Epoch 127/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1114
# Epoch 128/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1175
# Epoch 129/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1120
# Epoch 130/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1164
# Epoch 131/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1114
# Epoch 132/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1088
# Epoch 133/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1166
# Epoch 134/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.1024INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 47s 734us/sample - loss: 0.1025
# Epoch 135/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1114
# Epoch 136/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1121
# Epoch 137/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1112
# Epoch 138/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1139
# Epoch 139/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1045
# Epoch 140/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1205
# Epoch 141/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1122
# Epoch 142/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.0994INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 48s 755us/sample - loss: 0.0997
# Epoch 143/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1070
# Epoch 144/150
# 63329/63329 [==============================] - 10s 152us/sample - loss: 0.1042
# Epoch 145/150
# 63329/63329 [==============================] - 10s 153us/sample - loss: 0.1034
# Epoch 146/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1043
# Epoch 147/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.0992INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 48s 751us/sample - loss: 0.0991
# Epoch 148/150
# 62464/63329 [============================>.] - ETA: 0s - loss: 0.0960INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 63329/63329 [==============================] - 48s 760us/sample - loss: 0.0963
# Epoch 149/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1013
# Epoch 150/150
# 63329/63329 [==============================] - 10s 154us/sample - loss: 0.1042
